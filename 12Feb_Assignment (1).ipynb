# %%
# Ans1
# Exception handling

# Exception:
"""
Exception basically a runtime error occurred during tht execution of program
Exception is the base class for all the exceptions in Python
Exceptions are raised when the program is syntactically correct, but the code resulted in an error.
"""


# Difference between the Exception and the Syntax error in python 

"""
1 An Exception in Python is an error that occurs during the execution of a program.  
2  Generally Exceptions  are raised when  there is a logical  errors or a certain condtions fails in the program 
3 exceptions are raised during the execution of the code.

Exception handling can be handled using the :
try 
except
else
finally 
"""

# Syntax Error:

"""
1 syntax errors is that syntax errors occur due to incorrect syntax in the code and are detected by the Python interpreter before the code is executed.
2 Syntax errors can be fixed by correcting the syntax in the code 
3 Syntax errors are detected by the Python interpreter before the code is executed .
for example : writing the print wrongly
"""

# %%
# Ans2
"""
When an Exception is not handled  then execution of code terminate abnormally. it means
code i;e your program terminate abruptly """

# for Example
# Without handlig the error

age =10
result =age/0   
# due to this logical error that error called an excpetion occurrred  so  we need to handle this situation using  the exception handling 
print(a)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 9
#       6 # for Example
#       7 # Without handlig the error
#       8 age =10
# ----> 9 result =age/0
#      10 print(a)
#
# ZeroDivisionError: division by zero

# %%
# Ans3
# Try and Except Statement – Catching Exceptions
"""
Try and except statements are used to catch and handle exceptions in Python. 
"""
# try
"""
Statements that can raise exceptions are kept inside the try block
"""
# except
"""
the statements that handle the exception are written inside except block.

"""

# for example
import logging  

try :  # uisng the try
    
    logging.basicConfig(filename = "12feb.log" , level =logging.DEBUG , format = '%(asctime)s %(message)s' )  #using the logging
    f= open("pwsachin.txt" , 'r')
    logging.info(" code that may raise the exception ")
    
except Exception  as e : 
    
    logging.info(" error handled in this except block ")
    print("this is my except block " , e)
# Out:
# this is my except block  [Errno 2] No such file or directory: 'pwsachin.txt'

# %%
# Ans4 
import logging
"""
try
else
finally 
raise

"""
# 1 try 
"""
The try statement is used to enclose a block of code that may raise an exception.
If an exception is raised within this block of code, control is transferred to the except statement.
"""

# 2 else  :
"""
The else statement is executed if no exceptions were raised in the try block. 
i;e there is no error inside the try block
"""  
# Example of try and  else  statement 

try:
    logging.info(" # block to raise an exception ") # uising the logging 
    res = 5/3
    print(res)
    
except Exception as e :
    #block that may handle exception 
    print("Errore Hand,ig the block")
else:
    # code to be executed if no exceptions were raised
    print("Execute when no exceptions were raised ")

    
# 3 finally:

"""
The finally statement is used to specify code that must be executed regardless of whether an exception was raised or no
"""
# Example of the finally 


try:
    # block to raise an exception 
    res = 5/0
    print(res)
    
except Exception as e :
    logging.info(" except block that may handle exception") #using the logging
    #block that may handle exception 
    print("Errore Hand,ig the block")
finally :
    # code to be executed if no exceptions were raised
    print("it will execute in any situations ")

    
# 4 raise
"""
The raise statement is used to raise an exception.  
Basicaly it is an custom exception handling and rising
"""

# for example:

def Validate_age(birth_year):
    current_year = 2022
    age = current_year - birth_year
    if age < 0:
        # raising the exception 
        raise ValueError("Birth year is in the future.")
    return age

try:
    
    age = Validate_age(2030)
except ValueError as e:
    # handlig the exception
    print("Error:", e)
# Out:
# 1.6666666666666667
# Execute when no exceptions were raised
# Errore Hand,ig the block
# it will execute in any situations
# Error: Birth year is in the future.

# %%
# Ans5
# Custom Exceptions in python

"""
Custom exceptions in Python are user-defined exceptions that are raised in response to specific situations or errors that occur in a program. 
Custom exceptions are necessary because they provide a way to make a program respond in a specific way to errors or situations that are not covered by the built-in exceptions.
"""
# By creating the class and Using the raise keyword we raise the custom exceptions

"""
To create a custom exception, you can define a new class that inherits from the Exception class. The new class can have its own attributes and methods, but it should have a descriptive name that reflects the specific error or situation that it represents.
"""

# for using the logging 

import logging
# For Example:
class validate_number(Exception):
    logging.basicConfig(filename = "12feb.log", level = logging.info ,format = '%(asctime)s %(message)s' )
    logging.info(" Creating the class ") #using the logging
    
    def __init__(self,num):
        self.number= num
        # function to chek odd even  and raise the exception
        
    def Number_check(Number):
        if Number%2==0:
            logging.info("using the raise keyword to raisse the exception") #using the logging for further investigation
            raise validate_number("Number is Even")
            
        else:
            logging.info("else work when there is no exception in try block") #using the logging for further investigation
            print("correct ! Number is odd  ")
    
    try:   
        
            Number = int(input("Enter the Number to Check"))
            Number_check(Number)
            
    except Exception as e:
        logging.info("exception is handled here ")
        print(e)
# Out:
# Enter the Number to Check 55
# correct ! Number is odd

# %%
# Ans6
"""
 we are creating a custom class to handle the excption 
 """

# for Example 

import logging
# For Example:
class validate_number(Exception):
    logging.basicConfig(filename = "12feb.log", level = logging.info ,format = '%(asctime)s %(message)s' )
    logging.info(" Creating the class ") #using the logging
    
    def __init__(self,num):
        self.number= num
        # function to chek odd even  and raise the exception
        
    def Number_check(Number):
        if Number%2==0:
            logging.info("using the raise keyword to raisse the exception") #using the logging for further investigation
            raise validate_number("Number is Even")
            
        else:
            print("correct ! Number is odd  ")
    
    try:   
            logging.info("exception is riased here in try block") #using the logging for further investigation
            Number = int(input("Enter the Number to Check"))
            Number_check(Number)
            
    except Exception as e:
        logging.info("exception is handled here ")
        print(e)
