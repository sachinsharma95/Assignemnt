# %%
import logging
logging.basicConfig(filename="5MarchInfo.log", level=logging.INFO, format="%(asctime)s %(name)s %(message)s")

# %%
logging.info("import the bokeh which is necessary library")

import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
# Answer1
"""
Bokeh is a Python library used for creating interactive visualizations for web browsers. 
"""
from bokeh.plotting import figure, output_file,show

#data for the plottig the bokeh
x= [2,8,1,6]
y = [4,8,9,3]

p = figure(title = " Bokeh plot (line)")
p.title.text_font_size = "5em"
p.title.text_color = "red"
#labelling the x and=  y axis 
p.xaxis.axis_label = "xData"
p.yaxis.axis_label= "YData"

#plotting line graph using the bokeh
p.line(x,y, legend_label = "Line", line_width= 3,line_color= '#753a88' )
show(p)
# Out:
#   <div class="bk-root" id="ef0935ed-0c23-4913-8fa1-867c259e06c5" data-root-id="3933"></div>

# %%
# ANswer2
# glyphs
"""
In Bokeh, glyphs are the basic visual building blocks for creating interactive visualizations. 
Glyphs are geometric shapes that can be plotted at specific locations in a plot and can have different visual properties such as size, color, and transparency. Bokeh provides several different types of glyphs, including circles, squares, lines, and more.
"""

# Here's an example of how to add a circle glyph to a Bokeh plot using 

# Example

# Import the necessary libraries
from bokeh.plotting import figure, output_file, show

# Prepare the data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# Specify the output file
output_file("circle.html")

# Create a new plot with a title and axis labels
p = figure(title="Circle Plot", x_axis_label='X-axis', y_axis_label='Y-axis')

logging.info("Add a circle glyph with the x and y data")
p.circle(x, y, size=15, color="red", alpha=0.5)

# Show the plot
show(p)
# Out:
#   <div class="bk-root" id="07ae575f-d5ec-4a57-883c-0923c1ac48d0" data-root-id="6803"></div>

# %%
# Answer3
"""
you can customize the appearance of a plot in many ways, including the axes, title, legend, and more
"""

# Here is an Example


# Import the necessary libraries
from bokeh.plotting import figure, output_file, show
from bokeh.models import NumeralTickFormatter

# Prepare the data
x = [11, 12, 3, 14, 5]
y = [6, 17, 2, 14, 15]

# Specify the output file
output_file("custom.html")

# Create a new plot with a title and axis labels
p = figure(title="Custom Plot", x_axis_label='X-axis', y_axis_label='Y-axis', 
           plot_width=500, plot_height=400)

# Add a line glyph with the x and y data
p.line(x, y, legend_label="Line", line_width=2)

# Customize the appearance of the plot

logging.info("title axes and legends")
p.title.text_color = "red"
p.title.text_font = "italic"
p.title.text_font_size = "5em"
p.xaxis.axis_label_text_font = "arial"
p.yaxis.axis_label_text_font = "italic"
p.xaxis.axis_label_text_font_style = "italic"
p.yaxis.axis_label_text_font_style = "italic"
p.xaxis.axis_label_text_color = "blue"
p.yaxis.axis_label_text_color = "red"
p.xaxis.major_label_text_color = "green"
p.yaxis.major_label_text_color = "green"
p.xaxis.formatter = NumeralTickFormatter(format="0.00")
p.legend.location = "top_left"
p.legend.label_text_font_size = "14pt"
p.legend.background_fill_color = "beige"
p.legend.border_line_color = None

# Show the plot
show(p)
# Out:
#   <div class="bk-root" id="7f56be59-339f-44a1-9bdd-a579c0c71288" data-root-id="12006"></div>

# %%
# Answer4

# Bokeh server
"""
1 Bokeh server is a powerful tool that allows you to create and deploy interactive web applications with Bokeh plots that can be updated in real-time. 
2 The Bokeh server runs as a Python process on a server and provides a web-based user interface that can be accessed from a web browser
3  The Bokeh server allows you to build dynamic and interactive data 
"""


#  The basic steps to create an interactive Bokeh plot using the Bokeh server:
"""
1 Import the necessary libraries: bokeh, bokeh.plotting, and bokeh.server.
2 Define the initial data and plot configuration, and create the Bokeh plot using the figure() method
3 Define a Python function that updates the data or plot properties based on user input or other events.
4 Create a Bokeh ColumnDataSource object that represents the data that will be displayed in the plot.
5 Use the curdoc() function to get a reference to the current document, and add the Bokeh plot and other widgets to the document.
6 Start the Bokeh server using the bokeh serve command in the terminal.
7 Access the Bokeh application from a web browser at the specified URL, and interact with the plot and widgets in real-time.
"""
# Out:
# '\n1 Import the necessary libraries: bokeh, bokeh.plotting, and bokeh.server.\n2 Define the initial data and plot configuration, and create the Bokeh plot using the figure() method\n3 Define a Python function that updates the data or plot properties based on user input or other events.\n4 Create a Bokeh ColumnDataSource object that represents the data that will be displayed in the plot.\n5 Use the curdoc() function to get a reference to the current document, and add the Bokeh plot and other widgets to the document.\n6 Start the Bokeh server using the bokeh serve command in the terminal.\n7 Access the Bokeh application from a web browser at the specified URL, and interact with the plot and widgets in real-time.\n'

# %%
# ANswer5
# Embeddig with Flask


"""
Bokeh plots can be embedded into web pages or dashboards using Flask or Django web frameworks. 
The process involves creating a Flask or Django application, creating a view or route that generates the Bokeh plot, and embedding the plot into an HTML template that is rendered by the application.
"""
# Basic Steps to embed Bokeh into the flask
"""

Import the necessary libraries: bokeh, bokeh.plotting, and either flask or djang

Define the data and plot configuration, and create the Bokeh plot using the figure() method.

Define a Flask or Django view or route that generates the Bokeh plot using the bokeh.embed.components() function.

Create an HTML template that includes the necessary JavaScript and CSS files to render the Bokeh plot.


In the Flask or Django view or route, render the HTML template with the Bokeh plot embedded in it using the render_template() function.

Start the Flask or Django application and access the web page that includes the embedded Bokeh plot.
"""

# Dummy implementation of Bokeh with Flask  


"""
from flask import Flask, render_template
from bokeh.plotting import figure
from bokeh.embed import components

# Define the data and plot configuration
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plot = figure(title='Line Plot', x_axis_label='X', y_axis_label='Y')
plot.line(x, y, line_width=3)

# Define the Flask application
app = Flask(__name__)

# Define the Flask route that generates the Bokeh plot
@app.route('/')
def index():
    script, div = components(plot)
    return render_template('index.html', script=script, div=div)

# Define the HTML template that includes the Bokeh plot
<!DOCTYPE html>
<html>
  <head>
    <title>Bokeh Plot</title>
    {{ script|safe }}
  </head>
  <body>
    {{ div|safe }}
  </body>
</html>

"""
